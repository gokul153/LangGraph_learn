# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_community.tools import TavilySearchResults
from typing import TypedDict, Annotated
from langgraph.graph import add_messages, StateGraph, END
from dotenv import load_dotenv
from langgraph.prebuilt import ToolNode

load_dotenv()

class AgentState(TypedDict):
    messages: Annotated[list, add_messages]

search_tool = TavilySearchResults(max_results=2)
tools = [search_tool]

llm = ChatOpenAI(model="gpt-4o")
llm_with_tools = llm.bind_tools(tools=tools)

def model(state: AgentState):
    return {
        "messages": [llm_with_tools.invoke(state["messages"])], 
    }

def tools_router(state: AgentState):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    

tool_node = ToolNode(tools=tools)

graph = StateGraph(AgentState)

graph.add_node("model", model)
graph.add_node("tool_node", tool_node)
graph.set_entry_point("model")

graph.add_conditional_edges("model", tools_router)
graph.add_edge("tool_node", "model")

app = graph.compile()
# Out:
# C:\Users\gokul_das\AppData\Local\Temp\ipykernel_24988\3978034820.py:14: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-tavily package and should be used instead. To use it run `pip install -U :class:`~langchain-tavily` and import as `from :class:`~langchain_tavily import TavilySearch``.
#   search_tool = TavilySearchResults(max_results=2)

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
input = {
    "messages": ["What's the current weather in Bangalore?"]
}

events = app.stream(input=input, stream_mode="values")

for event in events: 
    print(event["messages"])
# Out:
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='4d8cb040-cf43-45f7-8bc9-aac1bdce687d')]
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='4d8cb040-cf43-45f7-8bc9-aac1bdce687d'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_TZoGhTs2TmVnqpce7D9vzRlH', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BzIF0Vl4zQ8QSZhzkHu00LB374rGf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--4ae66f77-a680-4e54-8574-84237e62bcd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_TZoGhTs2TmVnqpce7D9vzRlH', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='4d8cb040-cf43-45f7-8bc9-aac1bdce687d'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_TZoGhTs2TmVnqpce7D9vzRlH', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BzIF0Vl4zQ8QSZhzkHu00LB374rGf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--4ae66f77-a680-4e54-8574-84237e62bcd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_TZoGhTs2TmVnqpce7D9vzRlH', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"title": "Bangalore weather in July 2025 - Weather25.com", "url": "https://www.weather25.com/asia/india/karnataka/bangalore?page=month&month=July", "content": "Light rain shower\\nLight rain shower\\nPatchy rain possible\\nLight rain shower\\nPatchy rain possible\\nCloudy\\nOvercast\\nPatchy rain possible [...] weather25.com\\nSearch\\nweather in India\\nRemove from your favorite locations\\nAdd to my locations\\nShare\\nweather in India\\n\\n# Bangalore weather in July 2025\\n\\nPatchy rain possible\\nPatchy rain possible\\nPatchy rain possible\\nPatchy rain possible\\nLight rain shower\\nLight rain shower\\nLight rain shower\\nModerate or heavy rain shower\\nModerate or heavy rain shower\\nLight rain shower\\nPatchy rain possible\\nLight rain shower\\nModerate or heavy rain shower\\nLight rain shower\\n\\n## The average weather in Bangalore in July [...] | 27 Light rain shower 26° /20° | 28 Patchy rain possible 26° /20° | 29 Cloudy 27° /20° | 30 Overcast 28° /20° | 31 Patchy rain possible 26° /20° |  |  |", "score": 0.8021998}, {"title": "Bengaluru, Karnataka, India Weather Forecast - AccuWeather", "url": "https://www.accuweather.com/en/in/bengaluru/204108/weather-forecast/204108", "content": "# Bengaluru, Karnataka\\n\\nBengaluru\\n\\nKarnataka\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n## Today\\n\\n## Today\'s Weather\\n\\nThu, Jul 31\\n\\nBreezy this morning; otherwise, cloudy with a thunderstorm around this afternoon\\nHi: 85° [...] Tonight: Mainly clear this evening, then turning overcast\\nLo: 68°\\n\\n## Current Weather\\n\\n1:13 PM\\n\\n## Bengaluru Weather Radar\\n\\nBengaluru Weather Radar\\n\\n## Hourly Weather\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\n## 10-Day Weather Forecast\\n\\nToday\\n\\n7/31\\n\\nA t-storm around in the p.m.\\n\\nNight: Partly to mostly cloudy\\n\\nFri\\n\\n8/1\\n\\nLow clouds\\n\\nCloudy, a t-shower in spots\\n\\nSat\\n\\n8/2\\n\\nA stray afternoon t-shower", "score": 0.69199765}]', name='tavily_search_results_json', id='1059066a-4a2c-46b6-bc69-44be6d98404a', tool_call_id='call_TZoGhTs2TmVnqpce7D9vzRlH', artifact={'query': 'current weather in Bangalore', 'follow_up_questions': None, 'answer': None,  ...
# [HumanMessage(content="What's the current weather in Bangalore?", additional_kwargs={}, response_metadata={}, id='4d8cb040-cf43-45f7-8bc9-aac1bdce687d'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_TZoGhTs2TmVnqpce7D9vzRlH', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BzIF0Vl4zQ8QSZhzkHu00LB374rGf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--4ae66f77-a680-4e54-8574-84237e62bcd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_TZoGhTs2TmVnqpce7D9vzRlH', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{"title": "Bangalore weather in July 2025 - Weather25.com", "url": "https://www.weather25.com/asia/india/karnataka/bangalore?page=month&month=July", "content": "Light rain shower\\nLight rain shower\\nPatchy rain possible\\nLight rain shower\\nPatchy rain possible\\nCloudy\\nOvercast\\nPatchy rain possible [...] weather25.com\\nSearch\\nweather in India\\nRemove from your favorite locations\\nAdd to my locations\\nShare\\nweather in India\\n\\n# Bangalore weather in July 2025\\n\\nPatchy rain possible\\nPatchy rain possible\\nPatchy rain possible\\nPatchy rain possible\\nLight rain shower\\nLight rain shower\\nLight rain shower\\nModerate or heavy rain shower\\nModerate or heavy rain shower\\nLight rain shower\\nPatchy rain possible\\nLight rain shower\\nModerate or heavy rain shower\\nLight rain shower\\n\\n## The average weather in Bangalore in July [...] | 27 Light rain shower 26° /20° | 28 Patchy rain possible 26° /20° | 29 Cloudy 27° /20° | 30 Overcast 28° /20° | 31 Patchy rain possible 26° /20° |  |  |", "score": 0.8021998}, {"title": "Bengaluru, Karnataka, India Weather Forecast - AccuWeather", "url": "https://www.accuweather.com/en/in/bengaluru/204108/weather-forecast/204108", "content": "# Bengaluru, Karnataka\\n\\nBengaluru\\n\\nKarnataka\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n## Today\\n\\n## Today\'s Weather\\n\\nThu, Jul 31\\n\\nBreezy this morning; otherwise, cloudy with a thunderstorm around this afternoon\\nHi: 85° [...] Tonight: Mainly clear this evening, then turning overcast\\nLo: 68°\\n\\n## Current Weather\\n\\n1:13 PM\\n\\n## Bengaluru Weather Radar\\n\\nBengaluru Weather Radar\\n\\n## Hourly Weather\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\n## 10-Day Weather Forecast\\n\\nToday\\n\\n7/31\\n\\nA t-storm around in the p.m.\\n\\nNight: Partly to mostly cloudy\\n\\nFri\\n\\n8/1\\n\\nLow clouds\\n\\nCloudy, a t-shower in spots\\n\\nSat\\n\\n8/2\\n\\nA stray afternoon t-shower", "score": 0.69199765}]', name='tavily_search_results_json', id='1059066a-4a2c-46b6-bc69-44be6d98404a', tool_call_id='call_TZoGhTs2TmVnqpce7D9vzRlH', artifact={'query': 'current weather in Bangalore', 'follow_up_questions': None, 'answer': None,  ...

# %%
input = {
    "messages": ["What's the current weather in Bangalore?"]
}

events = app.stream(input=input, stream_mode="updates")

for event in events: 
    print(event)
# Out:
# {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_scsNBu5FEgs2b5GmsjKfFVeX', 'function': {'arguments': '{"query":"current weather in Bangalore"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 86, 'total_tokens': 107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BzIFDBcFgFSwWdMoR8TxpKA41wPy6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--6c3b0112-575e-4efc-9952-74f5bcda3bd0-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Bangalore'}, 'id': 'call_scsNBu5FEgs2b5GmsjKfFVeX', 'type': 'tool_call'}], usage_metadata={'input_tokens': 86, 'output_tokens': 21, 'total_tokens': 107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tool_node': {'messages': [ToolMessage(content='[{"title": "Bangalore weather in July 2025 - Weather25.com", "url": "https://www.weather25.com/asia/india/karnataka/bangalore?page=month&month=July", "content": "Light rain shower\\nLight rain shower\\nPatchy rain possible\\nLight rain shower\\nPatchy rain possible\\nCloudy\\nOvercast\\nPatchy rain possible [...] weather25.com\\nSearch\\nweather in India\\nRemove from your favorite locations\\nAdd to my locations\\nShare\\nweather in India\\n\\n# Bangalore weather in July 2025\\n\\nPatchy rain possible\\nPatchy rain possible\\nPatchy rain possible\\nPatchy rain possible\\nLight rain shower\\nLight rain shower\\nLight rain shower\\nModerate or heavy rain shower\\nModerate or heavy rain shower\\nLight rain shower\\nPatchy rain possible\\nLight rain shower\\nModerate or heavy rain shower\\nLight rain shower\\n\\n## The average weather in Bangalore in July [...] | 27 Light rain shower 26° /20° | 28 Patchy rain possible 26° /20° | 29 Cloudy 27° /20° | 30 Overcast 28° /20° | 31 Patchy rain possible 26° /20° |  |  |", "score": 0.8021998}, {"title": "Bengaluru, Karnataka, India Monthly Weather - AccuWeather", "url": "https://www.accuweather.com/en/in/bengaluru/204108/july-weather/204108", "content": "# Bengaluru, Karnataka\\n\\nBengaluru\\n\\nKarnataka\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n## Monthly\\n\\n## July\\n\\n## 2025\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### August 2025\\n\\n### September 2025 [...] ### October 2025\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\nTop Stories\\n\\nWeather Forecasts\\n\\nFlash flood threat ahead of dramatic cooldown in the Northeast\\n\\n11 hours ago\\n\\nWeather News\\n\\nTsunami waves hit Japan, Hawaii, Alaska after massive 8.8 earthquake o...\\n\\n14 hours ago\\n\\nSevere Weather\\n\\nStorms, flooding threaten Central and Eastern US\\n\\n11 hours ago\\n\\nRecreation [...] Toxic algae are turning South Australia’s coral reefs into graveyards\\n\\n2 days ago\\n\\nWeather News\\n\\nBaby sea turtles in Georgia are struggling to find the ocean this seas...\\n\\n2 days ago\\n\\n## Weather Near Bengaluru:\\n\\n...\\n\\n...\\n\\n...", "score": 0.51662046}]', name='tavily_search_results_json', id='b475506b-e76b-4d09-b823-34556869959d', tool_call_id='call_scsNBu5FEgs2b5GmsjKfFVeX', artifact={'query': 'current weather in Bangalore', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.weather25.com/asia/india/karnataka/bangalore?page=month&month=July', 'title': 'Bangalore weather in July 2025 - Weather25.com', 'content': 'Light rain shower\nLight rain shower\nPatchy rain possible\nLight rain shower\nPatchy rain possible\nCloudy\nOvercast\nPatchy rain possible [...] weather25.com\nSearch\nweather in India\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in India\n\n# Bangalore weather in July 2025\n\nPatchy rain possible\nPatchy rain possible\nPatchy rain possible\nPatchy rain possible\nLight rain shower\nLight rain shower\nLight rain shower\nModerate or heavy rain shower\nModerate or heavy rain shower\nLight rain shower\nPatchy rain possible\nLight rain shower\nModerate or heavy rain shower\nLight rain shower\n\n## The average weather in Bangalore in July [...] | 27 Light rain shower 26° /20° | 28 Patchy rain possible 26° /20° | 29 Cloudy 27° /20° | 30 Overcast 28° /20° | 31 Patchy rain possible 26° /20° |  |  |', 'score': 0.8021998, 'raw_content': None}, {'url': 'https://www.accuweather.com/ ...
# {'model': {'messages': [AIMessage(content="I wasn't able to retrieve the current weather in Bangalore from the available search results. You might want to check a weather website directly for the most up-to-date information.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 787, 'total_tokens': 821, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BzIFK5E0R8OLhEEGgh4EjTaG8bFgZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--8624ef76-9eb4-4013-9be6-1e550d326f37-0', usage_metadata={'input_tokens': 787, 'output_tokens': 34, 'total_tokens': 821, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events: 
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': ['Hi, how are you?']}}, 'name': 'LangGraph', 'tags': [], 'run_id': '9ee4077d-290c-400a-9c5c-8a623440b8f5', 'metadata': {}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='43103a63-4de0-4944-a552-9f34180a6cca')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': 'da582570-7276-423c-8878-a76fe43b6114', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28'}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='43103a63-4de0-4944-a552-9f34180a6cca')]]}}, 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='Hello', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=" I'm", additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' here', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' help', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' any', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' questions', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' or', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' information', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' need', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' How', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' assist', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' today', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='?', additional_kwargs={}, response_metadata={}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content="Hello! I'm here to help you with any questions or information you need. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc'), 'input': {'messages': [[HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='43103a63-4de0-4944-a552-9f34180a6cca')]]}}, 'run_id': '2a2317f4-e422-4db6-b2fe-1630b12134bc', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None, 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'moniterReactAgent', 'LANGSMITH_TRACING': 'true', 'revision_id': 'a85e90e-dirty'}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='43103a63-4de0-4944-a552-9f34180a6cca'), AIMessage(content="Hello! I'm here to help you with any questions or information you need. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')]}}, 'name': 'tools_router', 'tags': ['seq:step:3'], 'run_id': '1a58f9f9-2192-4651-a2cd-ec7977a57fcc', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28'}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='43103a63-4de0-4944-a552-9f34180a6cca'), AIMessage(content="Hello! I'm here to help you with any questions or information you need. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')]}}, 'run_id': '1a58f9f9-2192-4651-a2cd-ec7977a57fcc', 'name': 'tools_router', 'tags': ['seq:step:3'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'moniterReactAgent', 'LANGSMITH_TRACING': 'true', 'revision_id': 'a85e90e-dirty'}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5', 'da582570-7276-423c-8878-a76fe43b6114']}
# {'event': 'on_chain_stream', 'run_id': 'da582570-7276-423c-8878-a76fe43b6114', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28'}, 'data': {'chunk': {'messages': [AIMessage(content="Hello! I'm here to help you with any questions or information you need. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')]}}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="Hello! I'm here to help you with any questions or information you need. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')]}, 'input': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='43103a63-4de0-4944-a552-9f34180a6cca')]}}, 'run_id': 'da582570-7276-423c-8878-a76fe43b6114', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:3a1f672f-ef39-1b11-97ab-6ced65ff3b28', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'LANGSMITH_PROJECT': 'moniterReactAgent', 'LANGSMITH_TRACING': 'true', 'revision_id': 'a85e90e-dirty'}, 'parent_ids': ['9ee4077d-290c-400a-9c5c-8a623440b8f5']}
# {'event': 'on_chain_stream', 'run_id': '9ee4077d-290c-400a-9c5c-8a623440b8f5', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'model': {'messages': [AIMessage(content="Hello! I'm here to help you with any questions or information you need. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='Hi, how are you?', additional_kwargs={}, response_metadata={}, id='43103a63-4de0-4944-a552-9f34180a6cca'), AIMessage(content="Hello! I'm here to help you with any questions or information you need. How can I assist you today?", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'service_tier': 'default'}, id='run--2a2317f4-e422-4db6-b2fe-1630b12134bc')]}}, 'run_id': '9ee4077d-290c-400a-9c5c-8a623440b8f5', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'parent_ids': []}

# %%
input = {
    "messages": ["Hi, how are you?"]
}

events = app.astream_events(input=input, version="v2")

async for event in events: 
    if event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="", flush=True)
# Out:
# Hello! I'm here and ready to help you with any information or questions you have. How can I assist you today?
